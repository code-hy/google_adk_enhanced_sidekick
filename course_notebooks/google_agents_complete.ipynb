# %%
# !pip install nbmerge
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for nbmerge: filename=nbmerge-0.0.4-py2.py3-none-any.whl size=6478 sha256=37b8413db8f7f2046f86b0d5fc5e83699caff69f35c9deac98bc0cb3ac0ea476
#   Stored in directory: /home/codespace/.cache/pip/wheels/66/ec/e3/e3e9f9c3007f764582fcd1d93e2c9d296355985422f62c55f1
# Successfully built nbmerge
# ...
